# %% [markdown]
# **Homework 1 Collaboration**

# %% [markdown]
# Problem 1

# %% [markdown]
# Problem 2

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.linspace(0,(2*Vo)/g,100)
Vo=10
g=9.81
y= Vo*t -(1/2)*g*t**2
plt.plot(t, y)
plt.title('Plot of the function')
plt.xlabel('Time (s)')
plt.ylabel('Height (m)')
plt.grid()
plt.show()

# %% [markdown]
# Problem 3

# %% [markdown]
# Problem 4

# %%
n = int(input("Input integer"))

for num in range(1,n):
    summation1 = sum(range(1, n + 1))

comparison = n*((n + 1)/2)
    
print(summation1)
print(comparison)
# Out:
# Input integer 7
# 28
# 28.0
